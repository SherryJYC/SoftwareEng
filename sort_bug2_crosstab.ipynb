# %%
import numpy as np
import pandas as pd
import os
from scipy.stats import chi2_contingency as chi2
import math 
print("Finished")
# Out:
# Finished

# %%
def findStatis(coverage):
    totalS = len(coverage.loc[0,:])-1
    
    df = pd.DataFrame(np.nan,index=coverage.index,columns = ['s','r'])
    result = pd.DataFrame(np.nan, index =range(1,totalS), columns = ['chi-square','M','proportion','suspicious'])
    
    print(len(coverage.loc[0,:]))
    
    row = 1
    for i in range(1,totalS):
#         df['s'] = coverage.iloc[:,i]
#         df['r'] = coverage['r']
        s = pd.Categorical(coverage.iloc[:,i],categories=[0,1])
        r = pd.Categorical(coverage['r'],categories=[0,1])
        if checkDifference(s)==False:
            result.loc[row] = np.array([0,0,1,0])
            row+=1
            continue
        s1_tab = pd.crosstab(s,r,margins=True)
        s1_tab.index = ['uncovered','covered','coltotal']
        s1_tab.columns = ['passed','failed','rowtotal']
        print(s1_tab)
        
        stats, p, dof, expected = chi2(s1_tab)
        N = s1_tab.iloc[2]['rowtotal']
        m = stats/N
        
        proportion = s1_tab.iloc[1]['failed']/s1_tab.iloc[2]['failed']/(s1_tab.iloc[1]['passed']/s1_tab.iloc[2]['passed'])
        
        if proportion == 1:
            final = 0
        elif proportion < 1:
             final = -m
        else: final = m
        
        result.loc[row] = np.array([stats,m,proportion,final])
        row+=1
  
    return result

# %%
def checkDifference(s):
    for i in range(1,len(s)):
        if(s[i]!=s[i-1]):
            return True
    return False

# %%
def sort(result):
    rank_result = result.sort_values(by=['suspicious'],ascending = False)
    rank_result['rank'] = pd.Series(range(1,len(rank_result.index)+1),index = rank_result.index)
    print(rank_result)

# %%
if __name__ =="__main__":
    s = 'E:\\1819SEM1\\SoftwareEngineering\\Debugger'
    os.chdir(s)
    coverage = pd.read_csv('coverage_bug2.csv')
    print(coverage.index)
    print("============ Cross tab for each statement =============")
    result = findStatis(coverage)
    print("============== Suspicious levels ====================")
    print(result) 
    print("=================== Ranking ==========================")
    sort(result)
# Out:
# RangeIndex(start=0, stop=20, step=1)
# ============ Cross tab for each statement =============
# 92
#            passed  failed  rowtotal
# uncovered       6       8        14
# covered         5       1         6
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       6       9        15
# covered         5       0         5
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       6       9        15
# covered         5       0         5
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       9       9        18
# covered         2       0         2
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      10       9        19
# covered         1       0         1
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       9       9        18
# covered         2       0         2
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       5       1         6
# covered         6       8        14
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      11       1        12
# covered         0       8         8
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      11       1        12
# covered         0       8         8
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      11       1        12
# covered         0       8         8
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      11       8        19
# covered         0       1         1
# coltotal       11       9        20
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in double_scalars
#            passed  failed  rowtotal
# uncovered      11       1        12
# covered         0       8         8
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      11       2        13
# covered         0       7         7
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      11       2        13
# covered         0       7         7
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       5       9        14
# covered         6       0         6
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       5       9        14
# covered         6       0         6
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      10       9        19
# covered         1       0         1
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       9       9        18
# covered         2       0         2
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       9       9        18
# covered         2       0         2
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       9       9        18
# covered         2       0         2
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered      10       9        19
# covered         1       0         1
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered       8       9        17
# covered         3       0         3
# coltotal       11       9        20
#            passed  failed  rowtotal
# uncovered
# =================== Ranking ==========================
#     chi-square         M  proportion  suspicious  rank
# 85   20.000000  1.000000         inf    1.000000     1
# 14   16.296296  0.814815         inf    0.814815     2
# 15   16.296296  0.814815         inf    0.814815     3
# 18   16.296296  0.814815         inf    0.814815     4
# 16   16.296296  0.814815         inf    0.814815     5
# 20   13.162393  0.658120         inf    0.658120     6
# 19   13.162393  0.658120         inf    0.658120     7
# 13    2.780183  0.139009    1.629630    0.139009     8
# 17    1.286550  0.064327         inf    0.064327     9
# 69    0.000000  0.000000    1.000000    0.000000    10
# 68    0.000000  0.000000    1.000000    0.000000    11
# 60    0.000000  0.000000    1.000000    0.000000    12
# 59    0.000000  0.000000    1.000000    0.000000    13
# 58    0.000000  0.000000    1.000000    0.000000    14
# 1     0.000000  0.000000    1.000000    0.000000    15
# 71    0.000000  0.000000    1.000000    0.000000    16
# 57    0.000000  0.000000    1.000000    0.000000    17
# 56    0.000000  0.000000    1.000000    0.000000    18
# 55    0.000000  0.000000    1.000000    0.000000    19
# 54    0.000000  0.000000    1.000000    0.000000    20
# 53    0.000000  0.000000    1.000000    0.000000    21
# 52    0.000000  0.000000    1.000000    0.000000    22
# 51    0.000000  0.000000    1.000000    0.000000    23
# 50    0.000000  0.000000    1.000000    0.000000    24
# 49    0.000000  0.000000    1.000000    0.000000    25
# 70    0.000000  0.000000    1.000000    0.000000    26
# 76    0.000000  0.000000    1.000000    0.000000    27
# 72    0.000000  0.000000    1.000000    0.000000    28
# 81    0.000000  0.000000    1.000000    0.000000    29
# 89    0.000000  0.000000    1.000000    0.000000    30
# ..         ...       ...         ...         ...   ...
# 34    0.000000  0.000000    1.000000    0.000000    61
# 35    0.000000  0.000000    1.000000    0.000000    62
# 39    0.000000  0.000000    1.000000    0.000000    63
# 33    0.000000  0.000000    1.000000    0.000000    64
# 63    0.861244  0.043062    0.000000   -0.043062    65
# 41    0.861244  0.043062    0.000000   -0.043062    66
# 10    0.861244  0.043062    0.000000   -0.043062    67
# 42    1.818182  0.090909    0.000000   -0.090909    68
# 8     1.818182  0.090909    0.000000   -0.090909    69
# 43    1.818182  0.090909    0.000000   -0.090909    70
# 12    1.818182  0.090909    0.000000   -0.090909    71
# 67    1.818182  0.090909    0.000000   -0.090909    72
# 66    1.818182  0.090909    0.000000   -0.090909    73
# 65    1.818182  0.090909    0.000000   -0.090909    74
# 44    1.818182  0.090909    0.000000   -0.090909    75
# 4     2.780183  0.139009    0.244444   -0.139009    76
# 11    2.887701  0.144385    0.000000   -0.144385    77
# 9     2.887701  0.144385    0.000000   -0.144385    78
# 61    2.887701  0.144385    0.000000   -0.144385    79
# 40    2.887701  0.144385    0.000000   -0.144385    80
# 62    2.887701  0.144385    0.000000   -0.144385    81
# 38    2.887701  0.144385    0.000000   -0.144385    82
# 47    2.887701  0.144385    0.000000   -0.144385    83
# 64    2.887701  0.144385    0.000000   -0.144385    84
# 46    2.887701  0.144385    0.000000   -0.144385    85
# 7     5.454545  0.272727    0.000000   -0.272727    86
# 5     5.454545  0.272727    0.000000   -0.272727    87
# 37    7.012987  0.350649    0.000000   -0.350649    88
# 36    7.012987  0.350649    0.000000   -0.350649    89
# 83   20.000000  1.000000    0.000000   -1.000000    90
#
# [90 rows x 5 columns]
